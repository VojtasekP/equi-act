# %%
from escnn import gspaces, nn

r3 = gspaces.rot2dOnR2(maximum_frequency=2)

# %%
[r3.irrep(0), r3.irrep(1), r3.irrep(2)]
# Out:
# [SO(2)|[irrep_0]:1, SO(2)|[irrep_1]:2, SO(2)|[irrep_2]:2]

# %%
field = nn.FieldType(r3, [r3.irrep(0), r3.irrep(1), r3.irrep(2)])
field.uniform
# Out:
# False
